# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('LUCAS-SOIL-2018.xls')

# %%
df = df[df['NUTS_0']=='SE']
df.shape
# Out:
# (1906, 27)

# %%
cols = df.columns
for c in cols:
    if df[c].dtype == 'object':
        df[c] = df[c].str.strip()

df.dtypes
# Out:
# Depth                object
# POINTID               int64
# pH_CaCl2            float64
# pH_H2O              float64
# EC                  float64
# OC                   object
# CaCO3                object
# P                    object
# N                    object
# K                    object
# OC (20-30 cm)        object
# CaCO3 (20-30 cm)    float64
# Ox_Al               float64
# Ox_Fe               float64
# NUTS_0               object
# NUTS_1               object
# NUTS_2               object
# NUTS_3               object
# TH_LAT              float64
# TH_LONG             float64
# SURVEY_DATE          object
# Elev                  int64
# LC                   object
# LU                   object
# LC0_Desc             object
# LC1_Desc             object
# LU1_Desc             object
# dtype: object

# %%
df.head()
# Out:
#          Depth   POINTID  pH_CaCl2  pH_H2O     EC     OC CaCO3      P     N  \
# 9915   0-10 cm  44983842       3.8    4.11  61.90  378.8   nan   27.3  19.2
# 9916   0-10 cm  45024040       3.4    4.17   7.32   82.2   nan     22   4.1
# 10258  0-10 cm  45143854       3.1    4.06   5.77   57.5   nan  < LOD   2.6
# 10259  0-10 cm  45183718       5.5    5.98  26.44   62.4   nan     73   4.5
# 10261  0-10 cm  45743828       4.2    4.62   5.17   42.6   nan   21.1   1.8
#
#            K  ... NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE Elev   LC    LU  \
# 9915   292.7  ...  SE232  57.646988  12.961219     08/09/18  106  C31  U120
# 9916    87.5  ...  SE311  59.424224  13.182595     19/09/18  117  C33  U120
# 10258   63.7  ...  SE232  57.748526  13.238009     20/09/18  225  C21  U120
# 10259   77.8  ...  SE231  56.525760  13.199474     20/10/18   10  E20  U111
# 10261   38.5  ...  SE211  57.487029  14.215925     25/09/18  228  C23  U120
#
#         LC0_Desc                              LC1_Desc  \
# 9915    Woodland       Spruce dominated mixed woodland
# 9916    Woodland                  Other mixed woodland
# 10258   Woodland  Spruce dominated coniferous woodland
# 10259  Grassland    Grassland without tree/shrub cover
# 10261   Woodland             Other coniferous woodland
#
#                                                 LU1_Desc
# 9915                                            Forestry
# 9916                                            Forestry
# 10258                                           Forestry
# 10259  Agriculture (excluding fallow land and kitchen...
# 10261                                           Forestry
#
# [5 rows x 27 columns]

# %%
df['SURVEY_DATE']=pd.to_datetime(df['SURVEY_DATE'], format='%d/%m/%y')
df.head()
# Out:
#          Depth   POINTID  pH_CaCl2  pH_H2O     EC     OC CaCO3      P     N  \
# 9915   0-10 cm  44983842       3.8    4.11  61.90  378.8   nan   27.3  19.2
# 9916   0-10 cm  45024040       3.4    4.17   7.32   82.2   nan     22   4.1
# 10258  0-10 cm  45143854       3.1    4.06   5.77   57.5   nan  < LOD   2.6
# 10259  0-10 cm  45183718       5.5    5.98  26.44   62.4   nan     73   4.5
# 10261  0-10 cm  45743828       4.2    4.62   5.17   42.6   nan   21.1   1.8
#
#            K  ... NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE Elev   LC    LU  \
# 9915   292.7  ...  SE232  57.646988  12.961219   2018-09-08  106  C31  U120
# 9916    87.5  ...  SE311  59.424224  13.182595   2018-09-19  117  C33  U120
# 10258   63.7  ...  SE232  57.748526  13.238009   2018-09-20  225  C21  U120
# 10259   77.8  ...  SE231  56.525760  13.199474   2018-10-20   10  E20  U111
# 10261   38.5  ...  SE211  57.487029  14.215925   2018-09-25  228  C23  U120
#
#         LC0_Desc                              LC1_Desc  \
# 9915    Woodland       Spruce dominated mixed woodland
# 9916    Woodland                  Other mixed woodland
# 10258   Woodland  Spruce dominated coniferous woodland
# 10259  Grassland    Grassland without tree/shrub cover
# 10261   Woodland             Other coniferous woodland
#
#                                                 LU1_Desc
# 9915                                            Forestry
# 9916                                            Forestry
# 10258                                           Forestry
# 10259  Agriculture (excluding fallow land and kitchen...
# 10261                                           Forestry
#
# [5 rows x 27 columns]

# %%
for col in ['P', 'N', 'K']:
    df.loc[df[col]=='< LOD', col] = np.nan
    df[col]=df[col].astype(float)

# %%
for col in ['OC','CaCO3','OC (20-30 cm)','CaCO3 (20-30 cm)']:    
    df[col]=df[col].astype(float)

for col in ['NUTS_0','NUTS_1','NUTS_2','NUTS_3','LC','LU','LC0_Desc','LC1_Desc','LU1_Desc']:
    df[col]=df[col].astype('category')

df.dtypes
# Out:
# Depth                     category
# POINTID                      int64
# pH_CaCl2                   float64
# pH_H2O                     float64
# EC                         float64
# OC                         float64
# CaCO3                      float64
# P                          float64
# N                          float64
# K                          float64
# OC (20-30 cm)              float64
# CaCO3 (20-30 cm)           float64
# Ox_Al                      float64
# Ox_Fe                      float64
# NUTS_0                    category
# NUTS_1                    category
# NUTS_2                    category
# NUTS_3                    category
# TH_LAT                     float64
# TH_LONG                    float64
# SURVEY_DATE         datetime64[ns]
# Elev                         int64
# LC                        category
# LU                        category
# LC0_Desc                  category
# LC1_Desc                  category
# LU1_Desc                  category
# dtype: object

# %%
df.head(20)
# Out:
#          Depth   POINTID  pH_CaCl2  pH_H2O     EC     OC  CaCO3      P     N  \
# 9915   0-10 cm  44983842       3.8    4.11  61.90  378.8    NaN   27.3  19.2
# 9916   0-10 cm  45024040       3.4    4.17   7.32   82.2    NaN   22.0   4.1
# 10258  0-10 cm  45143854       3.1    4.06   5.77   57.5    NaN    NaN   2.6
# 10259  0-10 cm  45183718       5.5    5.98  26.44   62.4    NaN   73.0   4.5
# 10261  0-10 cm  45743828       4.2    4.62   5.17   42.6    NaN   21.1   1.8
# 10262  0-10 cm  45784544       3.7    4.32   3.77   17.4    NaN   11.5   1.4
# 10263  0-10 cm  45883824       3.6    4.22  14.60   79.8    NaN   23.3   4.8
#
#         LC0_Desc                              LC1_Desc  \
# 9915    Woodland       Spruce dominated mixed woodland
# 9916    Woodland                  Other mixed woodland
# 10258   Woodland  Spruce dominated coniferous woodland
# 10259  Grassland    Grassland without tree/shrub cover
# 10261   Woodland             Other coniferous woodland
# 10262   Woodland    Pine dominated coniferous woodland
# 10263   Woodland  Spruce dominated coniferous woodland
# 10264   Woodland       Spruce dominated mixed woodland
# 10266   Woodland    Pine dominated coniferous woodland
# 10597   Woodland       Spruce dominated mixed woodland
# 10598   Woodland                  Other mixed woodland
# 11070   Woodland    Pine dominated coniferous woodland
# 11071   Woodland    Pine dominated coniferous woodland
# 11297   Woodland    Pine dominated coniferous woodland
# 12033   Woodland                  Broadleaved woodland
# 12035   Woodland             Other coniferous woodland
# 12310   Woodland             Other coniferous woodland
# 14244   Woodland                  Other mixed woodland
# 15236   Woodland                  Broadleaved woodland
# 15237   Woodland         Pine dominated mixed woodland
#
#                                                 LU1_Desc
# 9915                                            Forestry
# 9916                                            Forestry
# 10258                                           Forestry
# 10259  Agriculture (excluding fallow land and kitchen...
# 10261                                           Forestry
# 10262                                           Forestry
# 10263                                           Forestry
# 10264                                           Forestry
# 10266                                           Forestry
# 10597                                           Forestry
# 10598                                           Forestry
# 11070                                           Forestry
# 11071                                           Forestry
# 11297                                           Forestry
# 12033                                           Forestry
# 12035                                           Forestry
# 12310                                           Forestry
# 14244                                           Forestry
# 15236                                           Forestry
# 15237                                           Forestry
#
# [20 rows x 27 columns]

# %%
cols = df.columns.tolist()
for index, c in enumerate(cols):
    cols[index] = c.replace(' ', '_')
df.columns = cols
df.columns
# Out:
# Index(['Depth', 'POINTID', 'pH_CaCl2', 'pH_H2O', 'EC', 'OC', 'CaCO3', 'P', 'N',
#        'K', 'OC_(20-30_cm)', 'CaCO3_(20-30_cm)', 'Ox_Al', 'Ox_Fe', 'NUTS_0',
#        'NUTS_1', 'NUTS_2', 'NUTS_3', 'TH_LAT', 'TH_LONG', 'SURVEY_DATE',
#        'Elev', 'LC', 'LU', 'LC0_Desc', 'LC1_Desc', 'LU1_Desc'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Depth                     category
# POINTID                      int64
# pH_CaCl2                   float64
# pH_H2O                     float64
# EC                         float64
# OC                         float64
# CaCO3                      float64
# P                          float64
# N                          float64
# K                          float64
# OC_(20-30_cm)              float64
# CaCO3_(20-30_cm)           float64
# Ox_Al                      float64
# Ox_Fe                      float64
# NUTS_0                    category
# NUTS_1                    category
# NUTS_2                    category
# NUTS_3                    category
# TH_LAT                     float64
# TH_LONG                    float64
# SURVEY_DATE         datetime64[ns]
# Elev                         int64
# LC                        category
# LU                        category
# LC0_Desc                  category
# LC1_Desc                  category
# LU1_Desc                  category
# dtype: object

# %%
df.to_json('LUCAS-SOIL-2018.json', orient='records', date_format='iso', double_precision=10, force_ascii=False, default_handler=None)
