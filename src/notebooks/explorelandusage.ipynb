# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('LUCAS-SOIL-2018.xls')

# %%
df = df[df['NUTS_0']=='SE']
df.shape
# Out:
# (1906, 27)

# %%
df.describe()
# Out:
#             POINTID     pH_CaCl2       pH_H2O           EC  CaCO3 (20-30 cm)  \
# count  1.906000e+03  1906.000000  1906.000000  1900.000000               0.0
# mean   4.646278e+07     3.967917     4.703806    12.826045               NaN
# std    1.173993e+06     0.825111     0.724075    12.920436               NaN
# min    4.392399e+07     2.600000     3.380000     1.970000               NaN
# 25%    4.556404e+07     3.400000     4.200000     5.067500               NaN
# 50%    4.640382e+07     3.800000     4.530000     8.875000               NaN
# 75%    4.722460e+07     4.300000     4.990000    15.550000               NaN
# max    4.950481e+07     7.200000     7.700000   132.600000               NaN
#
#            Ox_Al      Ox_Fe       TH_LAT      TH_LONG          Elev
# count  66.000000  66.000000  1906.000000  1906.000000   1906.000000
# mean    1.854545   4.089394    61.270910    16.267863    328.735047
# std     1.374289   2.442642     3.330711     2.783603   1104.732520
# ...
