# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('LUCAS-SOIL-2018.xls')

# %%
#First filter the points only for Sweden
#df = df[df['NUTS_0']=='SE']
df.shape
# Out:
# (18984, 27)

# %%
cols = df.columns
for c in cols:
    if df[c].dtype == 'object':
        df[c] = df[c].str.strip()

df.dtypes
# Out:
# Depth                object
# POINTID               int64
# pH_CaCl2            float64
# pH_H2O              float64
# EC                  float64
# OC                   object
# CaCO3                object
# P                    object
# N                    object
# K                    object
# OC (20-30 cm)        object
# CaCO3 (20-30 cm)    float64
# Ox_Al               float64
# Ox_Fe               float64
# NUTS_0               object
# NUTS_1               object
# NUTS_2               object
# NUTS_3               object
# TH_LAT              float64
# TH_LONG             float64
# SURVEY_DATE          object
# Elev                  int64
# LC                   object
# LU                   object
# LC0_Desc             object
# LC1_Desc             object
# LU1_Desc             object
# dtype: object

# %%
df.head(2)
# Out:
#      Depth   POINTID  pH_CaCl2  pH_H2O    EC   OC CaCO3      P    N    K  ...  \
# 0  0-20 cm  47862690       4.1    4.81  8.73  NaN   NaN  < LOD  NaN  NaN  ...
# 1  0-20 cm  47882704       4.1    4.93  5.06  NaN   NaN  < LOD  NaN  NaN  ...
#
#   NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE Elev   LC    LU  LC0_Desc  \
# 0  AT113  47.150238  16.134212     06/07/18  291  C23  U120  Woodland
# 1  AT113  47.274272  16.175359     06/07/18  373  C21  U120  Woodland
#
#                                LC1_Desc  LU1_Desc
# 0             Other coniferous woodland  Forestry
# 1  Spruce dominated coniferous woodland  Forestry
#
# [2 rows x 27 columns]

# %%
df['SURVEY_DATE']=pd.to_datetime(df['SURVEY_DATE'], format='%d/%m/%y')
df.head()
# Out:
#      Depth   POINTID  pH_CaCl2  pH_H2O     EC   OC CaCO3      P    N    K  \
# 0  0-20 cm  47862690       4.1    4.81   8.73  NaN   NaN  < LOD  NaN  NaN
# 1  0-20 cm  47882704       4.1    4.93   5.06  NaN   NaN  < LOD  NaN  NaN
# 2  0-20 cm  47982688       4.1    4.85  12.53  NaN   NaN    NaN  NaN  NaN
# 3  0-20 cm  48022702       5.5    5.80  21.10  NaN   NaN  < LOD  NaN  NaN
# 4  0-20 cm  48062708       6.1    6.48  10.89  NaN   NaN  < LOD  NaN  NaN
#
#    ... NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE Elev   LC    LU  LC0_Desc  \
# 0  ...  AT113  47.150238  16.134212   2018-07-06  291  C23  U120  Woodland
# 1  ...  AT113  47.274272  16.175359   2018-07-06  373  C21  U120  Woodland
# 2  ...  AT113  47.123260  16.289693   2018-06-02  246  C33  U120  Woodland
# 3  ...  AT113  47.245693  16.357506   2018-07-06  305  C22  U120  Woodland
# 4  ...  AT113  47.296372  16.416782   2018-07-05  335  C22  U120  Woodland
#
#                                LC1_Desc  LU1_Desc
# 0             Other coniferous woodland  Forestry
# 1  Spruce dominated coniferous woodland  Forestry
# 2                  Other mixed woodland  Forestry
# 3    Pine dominated coniferous woodland  Forestry
# 4    Pine dominated coniferous woodland  Forestry
#
# [5 rows x 27 columns]

# %%
for col in ['P', 'N', 'K']:
    df.loc[df[col]=='< LOD', col] = np.nan
    df.loc[df[col]=='<0.0', col] = np.nan
    df[col]=df[col].astype(float)

# %%
for col in ['OC','CaCO3','OC (20-30 cm)','CaCO3 (20-30 cm)']:
    df.loc[df[col]=='< LOD', col] = np.nan
    df.loc[df[col]=='<  LOD', col] = np.nan
    df.loc[df[col]=='<0.0', col] = np.nan
    df[col]=df[col].astype(float)

for col in ['NUTS_0','NUTS_1','NUTS_2','NUTS_3','LC','LU','LC0_Desc','LC1_Desc','LU1_Desc']:
    df[col]=df[col].astype('category')

df.dtypes
# Out:
# Depth                       object
# POINTID                      int64
# pH_CaCl2                   float64
# pH_H2O                     float64
# EC                         float64
# OC                         float64
# CaCO3                      float64
# P                          float64
# N                          float64
# K                          float64
# OC (20-30 cm)              float64
# CaCO3 (20-30 cm)           float64
# Ox_Al                      float64
# Ox_Fe                      float64
# NUTS_0                    category
# NUTS_1                    category
# NUTS_2                    category
# NUTS_3                    category
# TH_LAT                     float64
# TH_LONG                    float64
# SURVEY_DATE         datetime64[ns]
# Elev                         int64
# LC                        category
# LU                        category
# LC0_Desc                  category
# LC1_Desc                  category
# LU1_Desc                  category
# dtype: object

# %%
df.head(20)
# Out:
#       Depth   POINTID  pH_CaCl2  pH_H2O     EC  OC  CaCO3   P   N   K  ...  \
# 0   0-20 cm  47862690       4.1    4.81   8.73 NaN    NaN NaN NaN NaN  ...
# 1   0-20 cm  47882704       4.1    4.93   5.06 NaN    NaN NaN NaN NaN  ...
# 2   0-20 cm  47982688       4.1    4.85  12.53 NaN    NaN NaN NaN NaN  ...
# 3   0-20 cm  48022702       5.5    5.80  21.10 NaN    NaN NaN NaN NaN  ...
# 4   0-20 cm  48062708       6.1    6.48  10.89 NaN    NaN NaN NaN NaN  ...
# 5   0-20 cm  48122730       6.3    6.81  14.46 NaN    NaN NaN NaN NaN  ...
# 6   0-20 cm  48202738       5.8    6.37  17.08 NaN    NaN NaN NaN NaN  ...
# 7   0-20 cm  48222780       7.1    7.98  23.55 NaN    NaN NaN NaN NaN  ...
# 8   0-20 cm  48342774       7.4    8.09  22.61 NaN    NaN NaN NaN NaN  ...
# 9   0-20 cm  48442784       7.2    7.84  14.94 NaN    NaN NaN NaN NaN  ...
# 10  0-20 cm  48462776       7.6    8.15  30.90 NaN    NaN NaN NaN NaN  ...
# 11  0-20 cm  48482762       7.4    8.30  23.16 NaN    NaN NaN NaN NaN  ...
# 12  0-20 cm  46562790       7.1    7.52  14.82 NaN    NaN NaN NaN NaN  ...
# 13  0-20 cm  46662780       5.2    5.82  14.37 NaN    NaN NaN NaN NaN  ...
# 14  0-20 cm  46662794       3.9    4.74  12.06 NaN    NaN NaN NaN NaN  ...
# 15  0-20 cm  46722786       6.4    6.80  15.52 NaN    NaN NaN NaN NaN  ...
# 16  0-20 cm  46722792       5.4    5.84  28.20 NaN    NaN NaN NaN NaN  ...
# 17  0-20 cm  46782766       6.8    6.93  46.80 NaN    NaN NaN NaN NaN  ...
# 18  0-20 cm  46782778       6.3    6.80  19.56 NaN    NaN NaN NaN NaN  ...
# 19  0-20 cm  46842852       5.7    6.11  28.40 NaN    NaN NaN NaN NaN  ...
#
#     NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE Elev   LC    LU   LC0_Desc  \
# 0    AT113  47.150238  16.134212   2018-07-06  291  C23  U120   Woodland
# 1    AT113  47.274272  16.175359   2018-07-06  373  C21  U120   Woodland
# 2    AT113  47.123260  16.289693   2018-06-02  246  C33  U120   Woodland
# 3    AT113  47.245693  16.357506   2018-07-06  305  C22  U120   Woodland
# 4    AT113  47.296372  16.416782   2018-07-05  335  C22  U120   Woodland
# 5    AT111  47.488817  16.520595   2018-06-18  232  B18  U111   Cropland
# 6    AT111  47.554102  16.635559   2018-06-18  283  B32  U111   Cropland
# 7    AT112  47.928696  16.711158   2018-05-21  136  B82  U111   Cropland
# 8    AT112  47.865059  16.863852   2018-06-26  115  B32  U111   Cropland
# 9    AT112  47.946158  17.009260   2018-06-11  166  B14  U111   Cropland
# 10   AT112  47.872833  17.026032   2018-05-14  140  B13  U111   Cropland
# 11   AT112  47.745787  17.035368   2018-07-03  118  B16  U111   Cropland
# 12   AT121  48.131649  14.501514   2018-06-07  355  B55  U111   Cropland
# 13   AT121  48.036310  14.627389   2018-05-18  341  E20  U111  Grassland
# 14   AT121  48.161997  14.638865   2018-06-05  269  C10  U120   Woodland
# 15   AT121  48.086764  14.712668   2018-06-05  352  B13  U111   Cropland
# 16   AT121  48.140626  14.717676   2018-06-05  308  B16  U111   Cropland
# 17   AT121  47.903757  14.776151   2018-05-18  606  C31  U120   Woodland
# 18   AT121  48.011481  14.786259   2018-07-18  464  B55  U111   Cropland
# 19   AT124  48.672055  14.931104   2018-06-29  629  E20  U111  Grassland
#
#                                 LC1_Desc  \
# 0              Other coniferous woodland
# 1   Spruce dominated coniferous woodland
# 2                   Other mixed woodland
# 3     Pine dominated coniferous woodland
# 4     Pine dominated coniferous woodland
# 5                              Triticale
# 6                   Rape and turnip rape
# 7                              Vineyards
# 8                   Rape and turnip rape
# 9                                    Rye
# 10                                Barley
# 11                                 Maize
# 12                   Temporary grassland
# 13    Grassland without tree/shrub cover
# 14                  Broadleaved woodland
# 15                                Barley
# 16                                 Maize
# 17       Spruce dominated mixed woodland
# 18                   Temporary grassland
# 19    Grassland without tree/shrub cover
#
#                                              LU1_Desc
# 0                                            Forestry
# 1                                            Forestry
# 2                                            Forestry
# 3                                            Forestry
# 4                                            Forestry
# 5   Agriculture (excluding fallow land and kitchen...
# 6   Agriculture (excluding fallow land and kitchen...
# 7   Agriculture (excluding fallow land and kitchen...
# 8   Agriculture (excluding fallow land and kitchen...
# 9   Agriculture (excluding fallow land and kitchen...
# 10  Agriculture (excluding fallow land and kitchen...
# 11  Agriculture (excluding fallow land and kitchen...
# 12  Agriculture (excluding fallow land and kitchen...
# 13  Agriculture (excluding fallow land and kitchen...
# 14                                           Forestry
# 15  Agriculture (excluding fallow land and kitchen...
# 16  Agriculture (excluding fallow land and kitchen...
# 17                                           Forestry
# 18  Agriculture (excluding fallow land and kitchen...
# 19  Agriculture (excluding fallow land and kitchen...
#
# [20 rows x 27 columns]

# %%
cols = df.columns.tolist()
for index, c in enumerate(cols):
    cols[index] = c.replace(' ', '_')
df.columns = cols
df.columns
# Out:
# Index(['Depth', 'POINTID', 'pH_CaCl2', 'pH_H2O', 'EC', 'OC', 'CaCO3', 'P', 'N',
#        'K', 'OC_(20-30_cm)', 'CaCO3_(20-30_cm)', 'Ox_Al', 'Ox_Fe', 'NUTS_0',
#        'NUTS_1', 'NUTS_2', 'NUTS_3', 'TH_LAT', 'TH_LONG', 'SURVEY_DATE',
#        'Elev', 'LC', 'LU', 'LC0_Desc', 'LC1_Desc', 'LU1_Desc'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Depth                       object
# POINTID                      int64
# pH_CaCl2                   float64
# pH_H2O                     float64
# EC                         float64
# OC                         float64
# CaCO3                      float64
# P                          float64
# N                          float64
# K                          float64
# OC_(20-30_cm)              float64
# CaCO3_(20-30_cm)           float64
# Ox_Al                      float64
# Ox_Fe                      float64
# NUTS_0                    category
# NUTS_1                    category
# NUTS_2                    category
# NUTS_3                    category
# TH_LAT                     float64
# TH_LONG                    float64
# SURVEY_DATE         datetime64[ns]
# Elev                         int64
# LC                        category
# LU                        category
# LC0_Desc                  category
# LC1_Desc                  category
# LU1_Desc                  category
# dtype: object

# %%
df.to_json('LUCAS-SOIL-all-2018.json', orient='records', date_format='iso', double_precision=10, force_ascii=False, default_handler=None)
print(df.shape)
print('Done!')
# Out:
# (18984, 27)
# Done!
