# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_excel('/content/drive/MyDrive/AI4LS_Data/LUCAS-SOIL-2018.xls')

# %%
#First filter the points only for Sweden
#df = df[df['NUTS_0']=='SE']
df.shape
# Out:
# (18984, 27)

# %%
df.describe()
# Out:
#             POINTID      pH_CaCl2        pH_H2O            EC  \
# count  1.898400e+04  18983.000000  18983.000000  18975.000000
# mean   4.277080e+07      5.706379      6.259454     18.389964
# std    8.350827e+06      1.398597      1.319466     25.560630
# min    2.652197e+07      2.600000      3.340000      0.240000
# 25%    3.492293e+07      4.500000      5.120000      8.095000
# 50%    4.466391e+07      5.800000      6.290000     13.950000
# 75%    4.992278e+07      7.100000      7.500000     20.600000
# max    6.498167e+07      9.800000     10.430000   1295.600000
#
#        CaCO3 (20-30 cm)        Ox_Al        Ox_Fe        TH_LAT       TH_LONG  \
# count         14.000000  2510.000000  2510.000000  18984.000000  18984.000000
# mean         288.857143     1.171474     2.547171     48.689184     10.330166
# std          236.021139     1.243111     2.431786      7.779195     11.192492
# min            1.000000     0.000000     0.100000     34.690270    -10.149099
# 25%           64.500000     0.600000     1.000000     42.229369     -0.745365
# 50%          287.500000     0.900000     1.900000     47.338688     12.078146
# 75%          417.750000     1.300000     3.300000     53.424240     20.647825
# max          702.000000    34.700000    35.800000     69.956515     34.029660
#
#                Elev
# count  18984.000000
# mean     613.188211
# std     1461.681637
# min      -55.000000
# 25%      124.000000
# 50%      261.000000
# 75%      666.250000
# max    11464.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18984 entries, 0 to 18983
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Depth             18984 non-null  object
#  1   POINTID           18984 non-null  int64
#  2   pH_CaCl2          18983 non-null  float64
#  3   pH_H2O            18983 non-null  float64
#  4   EC                18975 non-null  float64
#  5   OC                18983 non-null  object
#  6   CaCO3             11221 non-null  object
#  7   P                 18958 non-null  object
#  8   N                 18983 non-null  object
#  9   K                 18983 non-null  object
#  10  OC (20-30 cm)     141 non-null    object
#  11  CaCO3 (20-30 cm)  14 non-null     float64
#  12  Ox_Al             2510 non-null   float64
#  13  Ox_Fe             2510 non-null   float64
#  14  NUTS_0            18984 non-null  object
#  15  NUTS_1            18984 non-null  object
#  16  NUTS_2            18984 non-null  object
#  17  NUTS_3            18984 non-null  object
#  18  TH_LAT            18984 non-null  float64
#  19  TH_LONG           18984 non-null  float64
#  20  SURVEY_DATE       18984 non-null  object
#  21  Elev              18984 non-null  int64
#  22  LC                18984 non-null  object
#  23  LU                18984 non-null  object
#  24  LC0_Desc          18984 non-null  object
#  25  LC1_Desc          18984 non-null  object
#  26  LU1_Desc          18984 non-null  object
# dtypes: float64(8), int64(2), object(17)
# memory usage: 3.9+ MB

# %%
for column in df.columns:
    print(f"Unique values in {column}: {df[column].nunique()}")
# Out:
# Unique values in Depth: 4
# Unique values in POINTID: 18984
# Unique values in pH_CaCl2: 80
# Unique values in pH_H2O: 557
# Unique values in EC: 3991
# Unique values in OC: 2539
# Unique values in CaCO3: 809
# Unique values in P: 1483
# Unique values in N: 394
# Unique values in K: 5633
# Unique values in OC (20-30 cm): 119
# Unique values in CaCO3 (20-30 cm): 14
# Unique values in Ox_Al: 75
# Unique values in Ox_Fe: 128
# Unique values in NUTS_0: 28
# Unique values in NUTS_1: 99
# Unique values in NUTS_2: 260
# Unique values in NUTS_3: 1035
# Unique values in TH_LAT: 18845
# Unique values in TH_LONG: 18984
# Unique values in SURVEY_DATE: 260
# Unique values in Elev: 1839
# Unique values in LC: 65
# Unique values in LU: 26
# Unique values in LC0_Desc: 8
# Unique values in LC1_Desc: 65
# Unique values in LU1_Desc: 26

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
# <ipython-input-9-f471181e404f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#                    POINTID  pH_CaCl2    pH_H2O        EC  CaCO3 (20-30 cm)  \
# POINTID           1.000000 -0.227756 -0.219786 -0.098808         -0.192683
# pH_CaCl2         -0.227756  1.000000  0.986954  0.217413          0.324135
# pH_H2O           -0.219786  0.986954  1.000000  0.172125          0.335215
# EC               -0.098808  0.217413  0.172125  1.000000         -0.046696
# CaCO3 (20-30 cm) -0.192683  0.324135  0.335215 -0.046696          1.000000
# Ox_Al             0.062258 -0.246886 -0.253661 -0.031823         -0.199406
# Ox_Fe             0.113065 -0.309646 -0.338538 -0.007328          0.120731
# TH_LAT            0.447964 -0.592064 -0.588712 -0.126129         -0.386181
# TH_LONG           0.987241 -0.272420 -0.261765 -0.111926          0.044096
# Elev              0.007913 -0.008990 -0.005550  0.000132         -0.233228
#
#                      Ox_Al     Ox_Fe    TH_LAT   TH_LONG      Elev
# POINTID           0.062258  0.113065  0.447964  0.987241  0.007913
# pH_CaCl2         -0.246886 -0.309646 -0.592064 -0.272420 -0.008990
# pH_H2O           -0.253661 -0.338538 -0.588712 -0.261765 -0.005550
# EC               -0.031823 -0.007328 -0.126129 -0.111926  0.000132
# CaCO3 (20-30 cm) -0.199406  0.120731 -0.386181  0.044096 -0.233228
# Ox_Al             1.000000  0.515174  0.124222  0.063568 -0.009195
# Ox_Fe             0.515174  1.000000  0.321234  0.106355 -0.008714
# TH_LAT            0.124222  0.321234  1.000000  0.520398 -0.044204
# TH_LONG           0.063568  0.106355  0.520398  1.000000  0.013702
# Elev             -0.009195 -0.008714 -0.044204  0.013702  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
for col in ['P', 'N', 'K']:
    df.loc[df[col]=='< LOD', col] = np.nan
    df.loc[df[col]=='<0.0', col] = np.nan
    df[col]=df[col].astype(float)
for col in ['OC','CaCO3','OC (20-30 cm)','CaCO3 (20-30 cm)']:
    df.loc[df[col]=='< LOD', col] = np.nan
    df.loc[df[col]=='<  LOD', col] = np.nan
    df.loc[df[col]=='<0.0', col] = np.nan
    df[col]=df[col].astype(float)

for col in ['NUTS_0','NUTS_1','NUTS_2','NUTS_3','LC','LU','LC0_Desc','LC1_Desc','LU1_Desc']:
    df[col]=df[col].astype('category')

df.dtypes



cols = df.columns
for c in cols:
    if df[c].dtype == 'object':
        df[c] = df[c].str.strip()

df.dtypes
# Out:
# Depth                 object
# POINTID                int64
# pH_CaCl2             float64
# pH_H2O               float64
# EC                   float64
# OC                   float64
# CaCO3                float64
# P                    float64
# N                    float64
# K                    float64
# OC (20-30 cm)        float64
# CaCO3 (20-30 cm)     float64
# Ox_Al                float64
# Ox_Fe                float64
# NUTS_0              category
# NUTS_1              category
# NUTS_2              category
# NUTS_3              category
# TH_LAT               float64
# TH_LONG              float64
# SURVEY_DATE           object
# Elev                   int64
# LC                  category
# LU                  category
# LC0_Desc            category
# LC1_Desc            category
# LU1_Desc            category
# dtype: object

# %%
df.head(2)
# Out:
#      Depth   POINTID  pH_CaCl2  pH_H2O    EC    OC  CaCO3   P    N      K  \
# 0  0-20 cm  47862690       4.1    4.81  8.73  12.4    3.0 NaN  1.1  101.9
# 1  0-20 cm  47882704       4.1    4.93  5.06  16.7    1.0 NaN  1.3   51.2
#
#    ...  NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE Elev   LC    LU  LC0_Desc  \
# 0  ...   AT113  47.150238  16.134212     06/07/18  291  C23  U120  Woodland
# 1  ...   AT113  47.274272  16.175359     06/07/18  373  C21  U120  Woodland
#
#                                LC1_Desc  LU1_Desc
# 0             Other coniferous woodland  Forestry
# 1  Spruce dominated coniferous woodland  Forestry
#
# [2 rows x 27 columns]

# %%
df['SURVEY_DATE']=pd.to_datetime(df['SURVEY_DATE'], format='%d/%m/%y')
df.head()
# Out:
#      Depth   POINTID  pH_CaCl2  pH_H2O     EC    OC  CaCO3     P    N      K  \
# 0  0-20 cm  47862690       4.1    4.81   8.73  12.4    3.0   NaN  1.1  101.9
# 1  0-20 cm  47882704       4.1    4.93   5.06  16.7    1.0   NaN  1.3   51.2
# 2  0-20 cm  47982688       4.1    4.85  12.53  47.5    1.0  12.3  3.1  114.8
# 3  0-20 cm  48022702       5.5    5.80  21.10  28.1    3.0   NaN  2.0  165.8
# 4  0-20 cm  48062708       6.1    6.48  10.89  19.4    2.0   NaN  2.2   42.1
#
#    ...  NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE Elev   LC    LU  LC0_Desc  \
# 0  ...   AT113  47.150238  16.134212   2018-07-06  291  C23  U120  Woodland
# 1  ...   AT113  47.274272  16.175359   2018-07-06  373  C21  U120  Woodland
# 2  ...   AT113  47.123260  16.289693   2018-06-02  246  C33  U120  Woodland
# 3  ...   AT113  47.245693  16.357506   2018-07-06  305  C22  U120  Woodland
# 4  ...   AT113  47.296372  16.416782   2018-07-05  335  C22  U120  Woodland
#
#                                LC1_Desc  LU1_Desc
# 0             Other coniferous woodland  Forestry
# 1  Spruce dominated coniferous woodland  Forestry
# 2                  Other mixed woodland  Forestry
# 3    Pine dominated coniferous woodland  Forestry
# 4    Pine dominated coniferous woodland  Forestry
#
# [5 rows x 27 columns]

# %%
df.head(20)
# Out:
#       Depth   POINTID  pH_CaCl2  pH_H2O     EC     OC  CaCO3     P     N  \
# 0   0-20 cm  47862690       4.1    4.81   8.73   12.4    3.0   NaN   1.1
# 1   0-20 cm  47882704       4.1    4.93   5.06   16.7    1.0   NaN   1.3
# 2   0-20 cm  47982688       4.1    4.85  12.53   47.5    1.0  12.3   3.1
# 3   0-20 cm  48022702       5.5    5.80  21.10   28.1    3.0   NaN   2.0
# 4   0-20 cm  48062708       6.1    6.48  10.89   19.4    2.0   NaN   2.2
# 5   0-20 cm  48122730       6.3    6.81  14.46   18.0    NaN  68.0   2.0
# 6   0-20 cm  48202738       5.8    6.37  17.08   12.5    NaN  58.1   1.4
# 7   0-20 cm  48222780       7.1    7.98  23.55   22.9   96.0  17.5   2.1
# 8   0-20 cm  48342774       7.4    8.09  22.61   29.1   86.0  62.2   2.9
# 9   0-20 cm  48442784       7.2    7.84  14.94   14.4    3.0   NaN   1.6
# 10  0-20 cm  48462776       7.6    8.15  30.90   21.8  112.0  22.3   2.0
# 11  0-20 cm  48482762       7.4    8.30  23.16   30.0  271.0  28.4   2.7
# 12  0-20 cm  46562790       7.1    7.52  14.82   15.2    1.0  44.5   1.9
# 13  0-20 cm  46662780       5.2    5.82  14.37   37.3    NaN  20.2   4.2
# 14  0-20 cm  46662794       3.9    4.74  12.06   41.2    NaN  19.4   3.8
# 15  0-20 cm  46722786       6.4    6.80  15.52   16.9    NaN  53.3   2.1
# 16  0-20 cm  46722792       5.4    5.84  28.20   21.0    NaN  22.3   2.5
# 17  0-20 cm  46782766       6.8    6.93  46.80  169.8    5.0  17.8  12.1
# 18  0-20 cm  46782778       6.3    6.80  19.56   31.7    NaN  77.2   3.4
# 19  0-20 cm  46842852       5.7    6.11  28.40   38.3    NaN  14.0   4.1
#
#         K  ...  NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE Elev   LC    LU  \
# 0   101.9  ...   AT113  47.150238  16.134212   2018-07-06  291  C23  U120
# 1    51.2  ...   AT113  47.274272  16.175359   2018-07-06  373  C21  U120
# 2   114.8  ...   AT113  47.123260  16.289693   2018-06-02  246  C33  U120
# 3   165.8  ...   AT113  47.245693  16.357506   2018-07-06  305  C22  U120
# 4    42.1  ...   AT113  47.296372  16.416782   2018-07-05  335  C22  U120
# 5   277.2  ...   AT111  47.488817  16.520595   2018-06-18  232  B18  U111
# 6   315.5  ...   AT111  47.554102  16.635559   2018-06-18  283  B32  U111
# 7   329.1  ...   AT112  47.928696  16.711158   2018-05-21  136  B82  U111
# 8   367.8  ...   AT112  47.865059  16.863852   2018-06-26  115  B32  U111
# 9   146.2  ...   AT112  47.946158  17.009260   2018-06-11  166  B14  U111
# 10  220.2  ...   AT112  47.872833  17.026032   2018-05-14  140  B13  U111
# 11  323.3  ...   AT112  47.745787  17.035368   2018-07-03  118  B16  U111
# 12  134.4  ...   AT121  48.131649  14.501514   2018-06-07  355  B55  U111
# 13  115.6  ...   AT121  48.036310  14.627389   2018-05-18  341  E20  U111
# 14  294.1  ...   AT121  48.161997  14.638865   2018-06-05  269  C10  U120
# 15  217.6  ...   AT121  48.086764  14.712668   2018-06-05  352  B13  U111
# 16  227.4  ...   AT121  48.140626  14.717676   2018-06-05  308  B16  U111
# 17  524.5  ...   AT121  47.903757  14.776151   2018-05-18  606  C31  U120
# 18  368.6  ...   AT121  48.011481  14.786259   2018-07-18  464  B55  U111
# 19  405.5  ...   AT124  48.672055  14.931104   2018-06-29  629  E20  U111
#
#      LC0_Desc                              LC1_Desc  \
# 0    Woodland             Other coniferous woodland
# 1    Woodland  Spruce dominated coniferous woodland
# 2    Woodland                  Other mixed woodland
# 3    Woodland    Pine dominated coniferous woodland
# 4    Woodland    Pine dominated coniferous woodland
# 5    Cropland                             Triticale
# 6    Cropland                  Rape and turnip rape
# 7    Cropland                             Vineyards
# 8    Cropland                  Rape and turnip rape
# 9    Cropland                                   Rye
# 10   Cropland                                Barley
# 11   Cropland                                 Maize
# 12   Cropland                   Temporary grassland
# 13  Grassland    Grassland without tree/shrub cover
# 14   Woodland                  Broadleaved woodland
# 15   Cropland                                Barley
# 16   Cropland                                 Maize
# 17   Woodland       Spruce dominated mixed woodland
# 18   Cropland                   Temporary grassland
# 19  Grassland    Grassland without tree/shrub cover
#
#                                              LU1_Desc
# 0                                            Forestry
# 1                                            Forestry
# 2                                            Forestry
# 3                                            Forestry
# 4                                            Forestry
# 5   Agriculture (excluding fallow land and kitchen...
# 6   Agriculture (excluding fallow land and kitchen...
# 7   Agriculture (excluding fallow land and kitchen...
# 8   Agriculture (excluding fallow land and kitchen...
# 9   Agriculture (excluding fallow land and kitchen...
# 10  Agriculture (excluding fallow land and kitchen...
# 11  Agriculture (excluding fallow land and kitchen...
# 12  Agriculture (excluding fallow land and kitchen...
# 13  Agriculture (excluding fallow land and kitchen...
# 14                                           Forestry
# 15  Agriculture (excluding fallow land and kitchen...
# 16  Agriculture (excluding fallow land and kitchen...
# 17                                           Forestry
# 18  Agriculture (excluding fallow land and kitchen...
# 19  Agriculture (excluding fallow land and kitchen...
#
# [20 rows x 27 columns]

# %%
cols = df.columns.tolist()
for index, c in enumerate(cols):
    cols[index] = c.replace(' ', '_')
df.columns = cols
df.columns
# Out:
# Index(['Depth', 'POINTID', 'pH_CaCl2', 'pH_H2O', 'EC', 'OC', 'CaCO3', 'P', 'N',
#        'K', 'OC_(20-30_cm)', 'CaCO3_(20-30_cm)', 'Ox_Al', 'Ox_Fe', 'NUTS_0',
#        'NUTS_1', 'NUTS_2', 'NUTS_3', 'TH_LAT', 'TH_LONG', 'SURVEY_DATE',
#        'Elev', 'LC', 'LU', 'LC0_Desc', 'LC1_Desc', 'LU1_Desc'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Depth                       object
# POINTID                      int64
# pH_CaCl2                   float64
# pH_H2O                     float64
# EC                         float64
# OC                         float64
# CaCO3                      float64
# P                          float64
# N                          float64
# K                          float64
# OC_(20-30_cm)              float64
# CaCO3_(20-30_cm)           float64
# Ox_Al                      float64
# Ox_Fe                      float64
# NUTS_0                    category
# NUTS_1                    category
# NUTS_2                    category
# NUTS_3                    category
# TH_LAT                     float64
# TH_LONG                    float64
# SURVEY_DATE         datetime64[ns]
# Elev                         int64
# LC                        category
# LU                        category
# LC0_Desc                  category
# LC1_Desc                  category
# LU1_Desc                  category
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is named df
df_encoded = df.copy()  # Create a copy to avoid modifying the original DataFrame

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Iterate through columns and apply label encoding
for column in df_encoded.columns:
    if df_encoded[column].dtype.name == 'category':
        df_encoded[column] = label_encoder.fit_transform(df_encoded[column])

# Display the resulting DataFrame
df_encoded.head()
# Out:
#      Depth   POINTID  pH_CaCl2  pH_H2O     EC    OC  CaCO3     P    N      K  \
# 0  0-20 cm  47862690       4.1    4.81   8.73  12.4    3.0   NaN  1.1  101.9
# 1  0-20 cm  47882704       4.1    4.93   5.06  16.7    1.0   NaN  1.3   51.2
# 2  0-20 cm  47982688       4.1    4.85  12.53  47.5    1.0  12.3  3.1  114.8
# 3  0-20 cm  48022702       5.5    5.80  21.10  28.1    3.0   NaN  2.0  165.8
# 4  0-20 cm  48062708       6.1    6.48  10.89  19.4    2.0   NaN  2.2   42.1
#
#    ...  NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE  Elev  LC  LU  LC0_Desc  \
# 0  ...       2  47.150238  16.134212   2018-07-06   291  47   3         7
# 1  ...       2  47.274272  16.175359   2018-07-06   373  45   3         7
# 2  ...       2  47.123260  16.289693   2018-06-02   246  50   3         7
# 3  ...       2  47.245693  16.357506   2018-07-06   305  46   3         7
# 4  ...       2  47.296372  16.416782   2018-07-05   335  46   3         7
#
#    LC1_Desc  LU1_Desc
# 0        32        12
# 1        55        12
# 2        36        12
# 3        42        12
# 4        42        12
#
# [5 rows x 27 columns]

# %%
df_encoded.dtypes
# Out:
# Depth                       object
# POINTID                      int64
# pH_CaCl2                   float64
# pH_H2O                     float64
# EC                         float64
# OC                         float64
# CaCO3                      float64
# P                          float64
# N                          float64
# K                          float64
# OC_(20-30_cm)              float64
# CaCO3_(20-30_cm)           float64
# Ox_Al                      float64
# Ox_Fe                      float64
# NUTS_0                       int64
# NUTS_1                       int64
# NUTS_2                       int64
# NUTS_3                       int64
# TH_LAT                     float64
# TH_LONG                    float64
# SURVEY_DATE         datetime64[ns]
# Elev                         int64
# LC                           int64
# LU                           int64
# LC0_Desc                     int64
# LC1_Desc                     int64
# LU1_Desc                     int64
# dtype: object

# %%
# List of columns to drop
columns_to_drop = ['OC_(20-30_cm)', 'CaCO3_(20-30_cm)', 'Ox_Al', 'Ox_Fe']

# Dropping the specified columns
df_encoded = df_encoded.drop(columns=columns_to_drop)
df_encoded.head()
# Out:
#      Depth   POINTID  pH_CaCl2  pH_H2O     EC    OC  CaCO3     P    N      K  \
# 0  0-20 cm  47862690       4.1    4.81   8.73  12.4    3.0   NaN  1.1  101.9
# 1  0-20 cm  47882704       4.1    4.93   5.06  16.7    1.0   NaN  1.3   51.2
# 2  0-20 cm  47982688       4.1    4.85  12.53  47.5    1.0  12.3  3.1  114.8
# 3  0-20 cm  48022702       5.5    5.80  21.10  28.1    3.0   NaN  2.0  165.8
# 4  0-20 cm  48062708       6.1    6.48  10.89  19.4    2.0   NaN  2.2   42.1
#
#    ...  NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE  Elev  LC LU  LC0_Desc  \
# 0  ...       2  47.150238  16.134212   2018-07-06   291  47  3         7
# 1  ...       2  47.274272  16.175359   2018-07-06   373  45  3         7
# 2  ...       2  47.123260  16.289693   2018-06-02   246  50  3         7
# 3  ...       2  47.245693  16.357506   2018-07-06   305  46  3         7
# 4  ...       2  47.296372  16.416782   2018-07-05   335  46  3         7
#
#    LC1_Desc  LU1_Desc
# 0        32        12
# 1        55        12
# 2        36        12
# 3        42        12
# 4        42        12
#
# [5 rows x 23 columns]
# Warning: Total number of columns (23) exceeds max_columns (20) limiting to first (20) columns.

# %%
import numpy as np

# Assuming df_encoded is your DataFrame
# Replace NaN values with 0 in the 'P' column
df_encoded['P'] = df_encoded['P'].replace(np.nan, 0).astype(float)

# Display the first 30 rows to verify the changes
df_encoded.head(10)
# Out:
#      Depth   POINTID  pH_CaCl2  pH_H2O     EC    OC  CaCO3     P    N      K  \
# 0  0-20 cm  47862690       4.1    4.81   8.73  12.4    3.0   0.0  1.1  101.9
# 1  0-20 cm  47882704       4.1    4.93   5.06  16.7    1.0   0.0  1.3   51.2
# 2  0-20 cm  47982688       4.1    4.85  12.53  47.5    1.0  12.3  3.1  114.8
# 3  0-20 cm  48022702       5.5    5.80  21.10  28.1    3.0   0.0  2.0  165.8
# 4  0-20 cm  48062708       6.1    6.48  10.89  19.4    2.0   0.0  2.2   42.1
# 5  0-20 cm  48122730       6.3    6.81  14.46  18.0    NaN  68.0  2.0  277.2
# 6  0-20 cm  48202738       5.8    6.37  17.08  12.5    NaN  58.1  1.4  315.5
# 7  0-20 cm  48222780       7.1    7.98  23.55  22.9   96.0  17.5  2.1  329.1
# 8  0-20 cm  48342774       7.4    8.09  22.61  29.1   86.0  62.2  2.9  367.8
# 9  0-20 cm  48442784       7.2    7.84  14.94  14.4    3.0   0.0  1.6  146.2
#
#    ...  NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE  Elev  LC LU  LC0_Desc  \
# 0  ...       2  47.150238  16.134212   2018-07-06   291  47  3         7
# 1  ...       2  47.274272  16.175359   2018-07-06   373  45  3         7
# 2  ...       2  47.123260  16.289693   2018-06-02   246  50  3         7
# 3  ...       2  47.245693  16.357506   2018-07-06   305  46  3         7
# 4  ...       2  47.296372  16.416782   2018-07-05   335  46  3         7
# 5  ...       0  47.488817  16.520595   2018-06-18   232  10  0         2
# 6  ...       0  47.554102  16.635559   2018-06-18   283  16  0         2
# 7  ...       1  47.928696  16.711158   2018-05-21   136  40  0         2
# 8  ...       1  47.865059  16.863852   2018-06-26   115  16  0         2
# 9  ...       1  47.946158  17.009260   2018-06-11   166   6  0         2
#
#    LC1_Desc  LU1_Desc
# 0        32        12
# 1        55        12
# 2        36        12
# 3        42        12
# 4        42        12
# 5        63         3
# 6        45         3
# 7        64         3
# 8        45         3
# 9        48         3
#
# [10 rows x 23 columns]

# %%
df_encoded['CaCO3'] = df_encoded['CaCO3'].replace(np.nan, 0).astype(float)
df_encoded.head()
# Out:
#      Depth   POINTID  pH_CaCl2  pH_H2O     EC    OC  CaCO3     P    N      K  \
# 0  0-20 cm  47862690       4.1    4.81   8.73  12.4    3.0   0.0  1.1  101.9
# 1  0-20 cm  47882704       4.1    4.93   5.06  16.7    1.0   0.0  1.3   51.2
# 2  0-20 cm  47982688       4.1    4.85  12.53  47.5    1.0  12.3  3.1  114.8
# 3  0-20 cm  48022702       5.5    5.80  21.10  28.1    3.0   0.0  2.0  165.8
# 4  0-20 cm  48062708       6.1    6.48  10.89  19.4    2.0   0.0  2.2   42.1
#
#    ...  NUTS_3     TH_LAT    TH_LONG  SURVEY_DATE  Elev  LC LU  LC0_Desc  \
# 0  ...       2  47.150238  16.134212   2018-07-06   291  47  3         7
# 1  ...       2  47.274272  16.175359   2018-07-06   373  45  3         7
# 2  ...       2  47.123260  16.289693   2018-06-02   246  50  3         7
# 3  ...       2  47.245693  16.357506   2018-07-06   305  46  3         7
# 4  ...       2  47.296372  16.416782   2018-07-05   335  46  3         7
#
#    LC1_Desc  LU1_Desc
# 0        32        12
# 1        55        12
# 2        36        12
# 3        42        12
# 4        42        12
#
# [5 rows x 23 columns]

# %%
df_encoded.columns
# Out:
# Index(['Depth', 'POINTID', 'pH_CaCl2', 'pH_H2O', 'EC', 'OC', 'CaCO3', 'P', 'N',
#        'K', 'NUTS_0', 'NUTS_1', 'NUTS_2', 'NUTS_3', 'TH_LAT', 'TH_LONG',
#        'SURVEY_DATE', 'Elev', 'LC', 'LU', 'LC0_Desc', 'LC1_Desc', 'LU1_Desc'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# Selecting features and target variable
features = ['pH_CaCl2', 'pH_H2O', 'EC', 'OC', 'CaCO3', 'P', 'N', 'K', 'NUTS_0', 'NUTS_1', 'NUTS_2', 'NUTS_3', 'Elev', 'LC', 'LU']
target = 'LC0_Desc'

X = df_encoded[features]
y = df_encoded[target]

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initializing XGBoost classifier
model = XGBClassifier()

# Training the model
model.fit(X_train, y_train)

# Making predictions on the test set
predictions = model.predict(X_test)

# Evaluating the model
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
print('\nClassification Report:\n', classification_report(y_test, predictions))
# Out:
# Accuracy: 0.9998244382022472
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       0.99      1.00      1.00       186
#            2       1.00      1.00      1.00      2253
#            3       1.00      1.00      1.00      1159
#            4       1.00      1.00      1.00       223
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00        17
#            7       1.00      1.00      1.00      1831
#
#     accuracy                           1.00      5696
#    macro avg       1.00      0.94      0.96      5696
# weighted avg       1.00      1.00      1.00      5696

# %%
#saving the built model
model.save_model('LC0_desc_prediction.model')
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [15:44:16] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)

# %%
from google.colab import files

# Replace 'your_model_filename.model' with the actual filename
files.download('LC0_desc_prediction.model')
